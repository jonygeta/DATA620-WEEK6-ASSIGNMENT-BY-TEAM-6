# %% [markdown]
# ## Data 620 - Week 6
#
# ### Team No. 6
#
# - Yohannes Deboch
# - Sherranette Tinapunan
#
# ### Video Presentation
#
# https://screencast-o-matic.com/watch/cqel0g04a2

# %% [markdown]
# ### Assignment
#
# Here is a dataset that shows a simple 2-node network:  the attendance of 18 Southern Women at 14 social events:
#
# - 1.Brief Description: http://vlado.fmf.uni-lj.si/pub/networks/data/ucinet/ucidata.htm#davis.   [For more background information, see also:http://rpackages.ianhowson.com/cran/latentnet/man/davis.html].  Small “musty” datasets like that from this 1941 study have proven very valuable in testing and comparing new network algorithms.
#
#
# - 2.Dataset:
# http://vlado.fmf.uni-lj.si/pub/networks/data/Ucinet/davis.dat
#
#
# - 3.Python code to create dataset:
# https://networkx.github.io/documentation/stable/auto_examples/algorithms/plot_davis_club.html

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import networkx as nx
import math
import matplotlib.pyplot as plt
import networkx.algorithms.bipartite as bipartite

# %% [markdown]
# ### Process Network
#
# The code below was taken from https://networkx.github.io/documentation/stable/auto_examples/algorithms/plot_davis_club.html.
#
# The davis_southern_women_graph() is is a bipartite graph.

# %% [markdown]
# - Create a graph object that represents the bipartite network of 18 women and 14 events.
# - Retrieve list of women
# - Retrieve list of clubs

# %%
G = nx.davis_southern_women_graph()
women = G.graph['top']
clubs = G.graph['bottom']

# %% [markdown]
# Print list of women

# %%
print(women)
# Out:
# ['Evelyn Jefferson', 'Laura Mandeville', 'Theresa Anderson', 'Brenda Rogers', 'Charlotte McDowd', 'Frances Anderson', 'Eleanor Nye', 'Pearl Oglethorpe', 'Ruth DeSand', 'Verne Sanderson', 'Myra Liddel', 'Katherina Rogers', 'Sylvia Avondale', 'Nora Fayette', 'Helen Lloyd', 'Dorothy Murchison', 'Olivia Carleton', 'Flora Price']

# %% [markdown]
# Print list of clubs.

# %%
print(clubs)
# Out:
# ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14']

# %%
print("Biadjacency matrix")
print(bipartite.biadjacency_matrix(G, women, clubs))
# Out:
# Biadjacency matrix
#   (0, 0)	1
#   (0, 1)	1
#   (0, 2)	1
#   (0, 3)	1
#   (0, 4)	1
#   (0, 5)	1
#   (0, 7)	1
#   (0, 8)	1
#   (1, 0)	1
#   (1, 1)	1
#   (1, 2)	1
#   (1, 4)	1
#   (1, 5)	1
#   (1, 6)	1
#   (1, 7)	1
#   (2, 1)	1
#   (2, 2)	1
#   (2, 3)	1
#   (2, 4)	1
#   (2, 5)	1
#   (2, 6)	1
#   (2, 7)	1
#   (2, 8)	1
#   (3, 0)	1
#   (3, 2)	1
#   :	:
#   (12, 7)	1
#   (12, 8)	1
#   (12, 9)	1
#   (12, 11)	1
#   (12, 12)	1
#   (12, 13)	1
#   (13, 5)	1
#   (13, 6)	1
#   (13, 8)	1
#   (13, 9)	1
#   (13, 10)	1
#   (13, 11)	1
#   (13, 12)	1
#   (13, 13)	1
#   (14, 6)	1
#   (14, 7)	1
#   (14, 9)	1
#   (14, 10)	1
#   (14, 11)	1
#   (15, 7)	1
#   (15, 8)	1
#   (16, 8)	1
#   (16, 10)	1
#   (17, 8)	1
#   (17, 10)	1

# %% [markdown]
# #### projected_graph(B, nodes, multigraph=False)
#
# > Returns the projection of B onto one of its node sets.
#
# > Returns the graph G that is the projection of the bipartite graph B onto the specified nodes. They retain their attributes and are connected in G if they have a common neighbor in B.
#
# Source:
# https://networkx.github.io/documentation/networkx1.9/reference/generated/networkx.algorithms.bipartite.projection.projected_graph.html
#
# Project bipartite graph onto the women nodes. The women are connected if they attend the same social club.

# %%
# project bipartite graph onto women nodes
W = bipartite.projected_graph(G, women)

# %% [markdown]
# Below shows the number of connections each woman has to other women.
# When there is a connection between two women, it means that they are co-members of the same club.

# %%
print("#Friends, Member")
for w in women:
     print('%d %s' % (W.degree(w), w))
# Out:
# #Friends, Member
# 17 Evelyn Jefferson
# 15 Laura Mandeville
# 17 Theresa Anderson
# 15 Brenda Rogers
# 11 Charlotte McDowd
# 15 Frances Anderson
# 15 Eleanor Nye
# 16 Pearl Oglethorpe
# 17 Ruth DeSand
# 17 Verne Sanderson
# 16 Myra Liddel
# 16 Katherina Rogers
# 17 Sylvia Avondale
# 17 Nora Fayette
# 17 Helen Lloyd
# 16 Dorothy Murchison
# 12 Olivia Carleton
# 12 Flora Price

# %% [markdown]
# #### bipartite.weighted_projected_graph(B, nodes, ratio=False)
#
# > Returns a weighted projection of B onto one of its node sets.
#
# > The weighted projected graph is the projection of the bipartite network B onto the specified nodes with weights representing the number of shared neighbors or the ratio between actual shared neighbors and possible shared neighbors if ratio=True [1]. The nodes retain their attributes and are connected in the resulting graph if they have an edge to a common node in the original graph.
#
# Source:
# https://networkx.github.io/documentation/networkx1.10/reference/generated/networkx.algorithms.bipartite.projection.weighted_projected_graph.html

# %%
# project bipartite graph onto women nodes keeping number of co-occurence
# the degree computed is weighted and counts the total number of shared contacts
W = bipartite.weighted_projected_graph(G, women)

# %%
print("#Friend meetings, Member")
for w in women:
    print('%d %s' % (W.degree(w, weight='weight'), w))
# Out:
# #Friend meetings, Member
# 50 Evelyn Jefferson
# 45 Laura Mandeville
# 57 Theresa Anderson
# 46 Brenda Rogers
# 24 Charlotte McDowd
# 32 Frances Anderson
# 36 Eleanor Nye
# 31 Pearl Oglethorpe
# 40 Ruth DeSand
# 38 Verne Sanderson
# 33 Myra Liddel
# 37 Katherina Rogers
# 46 Sylvia Avondale
# 43 Nora Fayette
# 34 Helen Lloyd
# 24 Dorothy Murchison
# 14 Olivia Carleton
# 14 Flora Price

# %% [markdown]
# Show graph of bipartite network (not projected)

# %%
plt.figure(3,figsize=(10,10)) 
#%matplotlib inline
#nx.draw(G, with_labels = True)
val_map = {'E1': 1.0, 'E2': 1.0,'E3': 1.0, 'E4': 1.0,  'E5': 1.0,  'E6': 1.0,  'E7': 1.0,  'E8': 1.0,  'E9': 1.0,
            'E10': 1.0,  'E11': 1.0, 'E12': 1.0, 'E13': 1.0,  'E14': 1.0}
values = [val_map.get(node, 0.5) for node in G.nodes()]
nx.draw(G, cmap=plt.get_cmap('viridis'), node_color=values, with_labels=True, font_color='black')
plt.show()

# %% [markdown]
# ### What can you infer about the relationships between (1) the women, and (2) the social events?

# %% [markdown]
# ### Affiliation Network of Women
#
# Connection between women is stronger when they are co-members of multiple clubs.
#
# In the graph below, the thicker and lighter the lines the stronger the relationships between two women.

# %%
plt.figure(3,figsize=(12,12)) 
womennet=bipartite.weighted_projected_graph(G, women, ratio=False)
weights=[edata['weight'] for f,t,edata in womennet.edges(data=True)]
nx.draw(womennet, width=weights, edge_color=weights, with_labels=True)

# %% [markdown]
# ### Top 10 Strong Relationships Among Women

# %%
for a, b, data in sorted(womennet.edges(data=True), key=lambda x: x[2]['weight'], reverse = True)[0:10]:
    print('{a} ---- {b}, {w}'.format(a=a, b=b, w=data['weight']))
# Out:
# Evelyn Jefferson ---- Theresa Anderson, 7
# Evelyn Jefferson ---- Brenda Rogers, 6
# Evelyn Jefferson ---- Laura Mandeville, 6
# Laura Mandeville ---- Brenda Rogers, 6
# Laura Mandeville ---- Theresa Anderson, 6
# Theresa Anderson ---- Brenda Rogers, 6
# Katherina Rogers ---- Sylvia Avondale, 6
# Sylvia Avondale ---- Nora Fayette, 6
# Katherina Rogers ---- Nora Fayette, 5
# Evelyn Jefferson ---- Frances Anderson, 4

# %% [markdown]
# ### Affiliation Network of Clubs
#
# In the graph below, the thicker and brighter the line is between two clubs, the stronger the relationships is. This  means that the clubs share many members.

# %%
plt.figure(3,figsize=(12,12)) 
clubnet=bipartite.weighted_projected_graph(G, clubs, ratio=False)
weights=[edata['weight'] for f,t,edata in clubnet.edges(data=True)]
nx.draw(clubnet,width=weights, edge_color=weights, with_labels=True, font_color='white')

# %% [markdown]
# ### Top 10 Strongest Club Relationships

# %%
for a, b, data in sorted(clubnet.edges(data=True), key=lambda x: x[2]['weight'], reverse = True)[0:10]:
    print('{a} ----- {b}, {w}'.format(a=a, b=b, w=data['weight']))
# Out:
# E8 ----- E9, 9
# E7 ----- E8, 8
# E5 ----- E8, 7
# E6 ----- E8, 7
# E3 ----- E5, 6
# E5 ----- E6, 6
# E5 ----- E7, 6
# E3 ----- E6, 5
# E3 ----- E8, 5
# E6 ----- E7, 5

# %% [markdown]
# ### Women with Most Club Memberships
#
# As you can see, the top women who belong to the most number of clubs are Evelyn Jefferson, Theresa Anderson, and Nora Fayette. Each one belongs to 8 different social clubs.

# %%
deg = nx.degree(G)
sorted(list(deg)[0:18], key=lambda x: x[1], reverse=True)
# Out:
# [('Evelyn Jefferson', 8),
#  ('Theresa Anderson', 8),
#  ('Nora Fayette', 8),
#  ('Laura Mandeville', 7),
#  ('Brenda Rogers', 7),
#  ('Sylvia Avondale', 7),
#  ('Katherina Rogers', 6),
#  ('Helen Lloyd', 5),
#  ('Charlotte McDowd', 4),
#  ('Frances Anderson', 4),
#  ('Eleanor Nye', 4),
#  ('Ruth DeSand', 4),
#  ('Verne Sanderson', 4),
#  ('Myra Liddel', 4),
#  ('Pearl Oglethorpe', 3),
#  ('Dorothy Murchison', 2),
#  ('Olivia Carleton', 2),
#  ('Flora Price', 2)]

# %% [markdown]
# ### Evelyn Jefferson
#
# In the earlier analysis, we know that Evelyn Jefferson is an influential member. She is connected to all the other women based on club affiliations. She is also among the women with the most club memberships. She is strongly connected to Theresa Anderson, Brenda Rogers, and Laura Mandeville.
#
#
# ### Theresa Anderson
#
# The strongest connection among the women are between Evelyn Jefferson and Theresa Anderson. Theresa Anderson is also connected to all the other women in the network based on club affiliations.

# %%
W = bipartite.projected_graph(G, women)
[n for n in W.neighbors('Evelyn Jefferson')]
# Out:
# ['Frances Anderson',
#  'Laura Mandeville',
#  'Brenda Rogers',
#  'Pearl Oglethorpe',
#  'Flora Price',
#  'Dorothy Murchison',
#  'Ruth DeSand',
#  'Olivia Carleton',
#  'Eleanor Nye',
#  'Theresa Anderson',
#  'Charlotte McDowd',
#  'Verne Sanderson',
#  'Myra Liddel',
#  'Katherina Rogers',
#  'Helen Lloyd',
#  'Sylvia Avondale',
#  'Nora Fayette']

# %% [markdown]
# These are the clubs that Evelyn Jefferson is affiliated with - 8 out of 14 possible clubs:

# %%
[n for n in G.neighbors('Evelyn Jefferson')]
# Out:
# ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E8', 'E9']

# %% [markdown]
# ### Club with the Most Members
#
# As you can see, club E8 has the most number of members - 14 members. This is followed by club E9 with 12 members.

# %%
sorted(list(deg)[18:32], key=lambda x: x[1], reverse=True)
# Out:
# [('E8', 14),
#  ('E9', 12),
#  ('E7', 10),
#  ('E5', 8),
#  ('E6', 8),
#  ('E3', 6),
#  ('E12', 6),
#  ('E10', 5),
#  ('E4', 4),
#  ('E11', 4),
#  ('E1', 3),
#  ('E2', 3),
#  ('E13', 3),
#  ('E14', 3)]

# %% [markdown]
# ### Members of Clubs E8 and E9
#
# Clubs E8 and E9 has 17 of possible 18 women. These two clubs are attended by almost all women. The women with the most club memberships are also participants of E8 and/or E9.

# %%
#all members of clubs E8 and E9
E8E9 = set([n for n in G.neighbors('E8')] + [n for n in G.neighbors('E9')])

#all women in the list
all_members = set(list(G.nodes())[0:18])

# %%
E8E9
# Out:
# {'Brenda Rogers',
#  'Dorothy Murchison',
#  'Eleanor Nye',
#  'Evelyn Jefferson',
#  'Flora Price',
#  'Frances Anderson',
#  'Helen Lloyd',
#  'Katherina Rogers',
#  'Laura Mandeville',
#  'Myra Liddel',
#  'Nora Fayette',
#  'Olivia Carleton',
#  'Pearl Oglethorpe',
#  'Ruth DeSand',
#  'Sylvia Avondale',
#  'Theresa Anderson',
#  'Verne Sanderson'}

# %% [markdown]
# #### The only member that's not participating in E8 and E9 is Charlotte McDowd

# %%
all_members^E8E9
# Out:
# {'Charlotte McDowd'}

# %% [markdown]
# ### Conclusion
#
# The member that has the strongest connection to other women based on club affiliation is Evelyn Jefferson. Evelyn Jefferson is a member of 8 out of the 14 social clubs. She is connected to all 17 other women.
#
# The top social clubs are E8 and E9. Together these two clubs have 17 out of the possible 18 women as members. The only woman who is not a member of these two top clubs is Charlotte McDowd.

# %% [markdown]
# ---
# Team No. 6
